# %% [markdown]
# # Laboratorio 001
# ---

# %% [markdown]
# ## Verificación de de paquetes esenciales para el laboratorio.

# %%
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import scipy
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 2.5.3
# Pandas: 3.0.5
# Matplotlib: 3.11.2
# Scikit-learn: 1.9.1
# SciPy: 1.18.1

# %% [markdown]
# > Se han descargado las librerías requeridas mediante PIP para el laboratorio, las cuales son jupyter, ipykernel, pandas, scikit-learn, scipy y matplotlib. Luego mediante practica.ipynb verificamos estas librerías (numpy, pandas, matplotlib, sklearn y scipy) en las primeras celdas, importándolas y luego imprimiendo sus respectivas versiones, luego ejecutamos la celda y efectivamente todas las librerías están correctas.

# %% [markdown]
# ## Parte B: Verificación funcional

# %% [markdown]
# > Primero importamos los paquetes necesarios los cuales son numpy, pandas y  matplotlib, los cuales usaran alias para simplicidad con la declaración `as`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# > Aquí fijamos la semilla de aleatoriedad de numpy en 42, para que las futuras iteraciones nos den el mismo resultado, luego en `n` definimos en tamaño de la muestra (300), luego se generan 300 números que representan la hora, cada valor puede ser entre 0 y 23. Con el `monto` simulamos el dinero transferido usando una distribución exponencial sumándole 10 para que sea el mínimo monto.

# %%
np.random.seed(42)
n = 300

hora = np.random.randint(0, 24, n)
monto = np.random.exponential(scale=150, size=n) + 10
# Out:
# array([ 6, 19, 14, 10,  7, 20,  6, 18, 22, 10, 10, 23, 20,  3,  7, 23,  2,
#        21, 20,  1, 23, 11,  5,  1, 20,  0, 11, 21, 11, 16,  9, 15, 14, 14,
#        18, 11, 22, 19,  2,  4, 18,  6, 20,  8,  6, 17,  3, 13, 17,  8, 20,
#         1, 19, 14,  6, 11,  7, 14,  2, 13, 16,  3, 17,  7,  3,  1,  5, 21,
#         9,  3, 21, 17, 11,  1,  9,  3, 13, 15, 14,  7, 13, 22,  7, 20, 15,
#        12, 17, 14, 20, 23, 12,  8, 14, 12,  0,  6,  8, 23,  0, 11,  7, 23,
#        10, 18, 16,  7,  2,  2,  0,  4,  9,  6,  8,  6,  8,  7, 11,  1,  0,
#        15, 22, 22, 23,  4,  2, 11,  7, 21,  2,  0,  2,  4, 14, 13,  2,  0,
#         4, 22, 13,  6,  8, 14, 14,  9, 12, 18,  6, 16, 19,  3,  4, 22,  6,
#        12, 14, 10,  3, 12,  6, 18, 21,  1,  9, 12, 20,  5, 11, 11, 19, 10,
#        22,  6,  0,  0, 19, 12,  8,  2,  6,  5,  7,  8,  4,  0, 18,  9, 11,
#        23, 14, 21, 23,  8, 19, 16, 16, 19, 11,  6,  1,  2, 16,  4, 16, 23,
# ...
