# %% [markdown]
# # Laboratorio 001
# ---

# %% [markdown]
# ## Verificación de de paquetes esenciales para el laboratorio.

# %%
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import scipy
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 2.5.3
# Pandas: 3.0.5
# Matplotlib: 3.11.2
# Scikit-learn: 1.9.1
# SciPy: 1.18.1

# %% [markdown]
# Se han descargado las librerías requeridas mediante PIP para el laboratorio, las cuales son jupyter, ipykernel, pandas, scikit-learn, scipy y matplotlib. Luego mediante practica.ipynb verificamos estas librerías (numpy, pandas, matplotlib, sklearn y scipy) en las primeras celdas, importándolas y luego imprimiendo sus respectivas versiones, luego ejecutamos la celda y efectivamente todas las librerías están correctas.
